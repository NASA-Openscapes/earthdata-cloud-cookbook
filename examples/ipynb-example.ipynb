# %% [markdown]
# ---
# title: .ipynb notebook (python)
# ---

# %% [markdown]
# ## I'm editing this in Jupyter Lab  <a id="1.1"></a>
#
# And I will execute the cells as I develop the notebook. Then the executed notebook will display in our Cookbook through Quarto.
#
# #### Import the required packages and set the input/working directory to run this Jupyter Notebook locally.

# %%
import numpy as np
import matplotlib.pyplot as plt

r = np.arange(0, 2, 0.01)
theta = 2 * np.pi * r
fig, ax = plt.subplots(subplot_kw={'projection': 'polar'})
ax.plot(theta, r)
ax.set_rticks([0.5, 1, 1.5, 2])
ax.grid(True)
plt.show()
